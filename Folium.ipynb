#     [70.92565155029297, 28.53869438171398],
#     [70.92075347900396, 28.511621475219727],
#     [70.9196243286134, 28.485881805419922],
#     [70.92367553710949, 28.467487335205192],
#     [70.93348693847662, 28.43948936462408],
#     [70.94001770019537, 28.405277252197322],
#     [70.94076538085943, 28.38020324707037],
#     [70.93824768066406, 28.32988929748541],
#     [70.93870544433605, 28.302732467651424],
#     [70.94185638427734, 28.256042480468807],
#     [70.95372772216803, 28.200632095337028],
#     [70.95861053466797, 28.18431282043457],
#     [70.97069549560553, 28.16602516174322],
#     [70.98382568359375, 28.145633697509766],
#     [70.99626159667974, 28.133836746215877],
#     [71.00145721435558, 28.121688842773438],
#     [71.00502014160162, 28.10678291320812],
#     [71.01591491699224, 28.079696655273438],
#     [71.02745819091797, 28.0607204437257],
#     [71.02770996093756, 28.058944702148438],
#     [71.03015899658203, 28.041419982910213],
#     [71.0338821411134, 28.01862144470215],
#     [71.04122161865234, 27.985555648803825],
#     [71.04908752441412, 27.97220802307129],
#     [71.06407928466797, 27.951089859008846],
#     [71.06813049316406, 27.932928085327262],
#     [71.07632446289062, 27.903329849243164],
#     [71.0855560302735, 27.892280578613338],
#     [71.09476470947277, 27.879373550415096],
#     [71.10172271728521, 27.858381271362248],
#     [71.10097503662115, 27.84168624877941],
#     [71.1026611328125, 27.826808929443473],
#     [71.10758209228516, 27.8139705657959],
#     [71.11640930175787, 27.804435729980582],
#     [71.1167831420899, 27.804521560668945],
#     [71.12506103515636, 27.792251586914006]]]}}

# %%
df_gp = gpd.read_file('punjab_districts.geojson')
df_gp = df_gp[['district','geometry']]
df_gp.drop(df_gp.index[21] , inplace=True)

# %%
df_gp.reset_index(drop=True,inplace=True)
df_gp.head(4)
# Out:
#           district                                           geometry
# 0     Bahawalnagar  POLYGON ((72.78970 28.96686, 72.78582 28.96537...
# 1       Bahawalpur  POLYGON ((71.89630 27.95684, 71.89311 27.95511...
# 2   Rahim Yar Khan  POLYGON ((71.12506 27.79225, 71.08701 27.77679...
# 3  Dera Ghazi Khan  POLYGON ((70.80437 30.66216, 70.79614 30.63932...

# %%
df = pd.read_csv('data2.csv')
df.head(4)
# Out:
#      district  Total Calls  Emergency Calls  Road Accidents  Medical   Fire  \
# 0      Lahore     19008571          1024477          474873   438171  29943
# 1  Rawalpindi      6847824           176946           73761    78969   7718
# 2  Faisalabad      9172915           519353          200160   233372  12832
# 3      Multan      6318038           376382          123717   215388   7231
#
#    Building Collapse  Crime Incidents  Drowning  Explosion   Misc  Fake Calls  \
# 0               1429            25472       984        409  53196        1755
# 1                145             5466       216        142  10529         155
# 2               1324            26946       702        130  43887         214
# 3                303            10313       305         57  19068         174
#
#    Patients Rescued
# 0           1014268
# 1            191363
# 2            543478
# 3            421227

# %%
# create a numpy array of length 6 and has linear spacing from the minium total immigration to the maximum total immigration
threshold_scale = np.linspace(df['Fire'].min(),
                              df['Fire'].max(),
                              6, dtype=int)
threshold_scale = threshold_scale.tolist() # change the numpy array to a list

#Create a map:
Map = folium.Map(location=[31.17, 72.7097], zoom_start=6.5, tiles='Stamen toner')

#Create a layer
Map.choropleth(geo_data="punjab_districts.geojson",
                     fill_color='YlGn', fill_opacity=2, line_opacity=0.2,
#                      threshold_scale = [60000,70000,80000,90000,100000,110000],
                     threshold_scale = threshold_scale,
                     data = df,
                     key_on='feature.properties.district',
                     columns = ['district', 'Fire'],
                     legend_name='Fire Incidents'
                     
                     )

for i in range(len(df_gp)):
    gs = folium.GeoJson(df_gp.iloc[i:i+1],
                        style_function=lambda i: {
#                         'fillColor': 'black' if 'a' in i['properties']['district'].lower() else '#ffff00',
#                         'color' : 'black',
#                         'weight' : 1.5,
                        })
    label = '{}: {} Fire incidents '.format(df['district'][i], df['Fire'][i])
    folium.Popup(label).add_to(gs)
    gs.add_to(Map)
Map
# Out:
# /home/drogon/.local/lib/python3.6/site-packages/folium/folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.6/site-packages/folium/folium.py in _repr_html_(self, **kwargs)
#     291             self._parent = None
#     292         else:
# --> 293             out = self._parent._repr_html_(**kwargs)
#     294         return out
#     295
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in _repr_html_(self, **kwargs)
#     326
#     327         """
# --> 328         html = self.render(**kwargs)
#     329         html = "data:text/html;charset=utf-8;base64," + base64.b64encode(html.encode('utf8')).decode('utf8')  # noqa
#     330
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in render(self, **kwargs)
#     319         """Renders the HTML representation of the element."""
#     320         for name, child in self._children.items():
# --> 321             child.render(**kwargs)
#     322         return self._template.render(this=self, kwargs=kwargs)
#     323
#
# ~/.local/lib/python3.6/site-packages/folium/folium.py in render(self, **kwargs)
#     368             '</style>'), name='map_style')
#     369
# --> 370         super(Map, self).render(**kwargs)
#     371
#     372     def fit_bounds(self, bounds, padding_top_left=None,
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in render(self, **kwargs)
#     631
#     632         for name, element in self._children.items():
# --> 633             element.render(**kwargs)
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in render(self, **kwargs)
#    1168             self.color_scale._parent = self._parent
#    1169
# -> 1170         super(Choropleth, self).render(**kwargs)
#    1171
#    1172
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in render(self, **kwargs)
#     631
#     632         for name, element in self._children.items():
# --> 633             element.render(**kwargs)
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in render(self, **kwargs)
#     569                                         self)
#     570             if self.style:
# --> 571                 self.style_map = mapper.get_style_map(self.style_function)
#     572             if self.highlight:
#     573                 self.highlight_map = mapper.get_highlight_map(
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in get_style_map(self, style_function)
#     589     def get_style_map(self, style_function):
#     590         """Return a dict that maps style parameters to features."""
# --> 591         return self._create_mapping(style_function, 'style')
#     592
#     593     def get_highlight_map(self, highlight_function):
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in _create_mapping(self, func, switch)
#     599         mapping = {}
#     600         for feature in self.data['features']:
# --> 601             content = func(feature)
#     602             if switch == 'style':
#     603                 for key, value in content.items():
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in style_function(x)
#    1128
#    1129         def style_function(x):
# -> 1130             color, opacity = color_scale_fun(x)
#    1131             return {
#    1132                 'weight': line_weight,
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in color_scale_fun(x)
#    1121
#    1122                 color_idx = np.digitize(value_of_x, bin_edges, right=False) - 1
# -> 1123                 return color_range[color_idx], fill_opacity
#    1124
#    1125         else:
#
# IndexError: list index out of range

# %%
Map.save(outfile='Map.html')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-c902fbc898f5> in <module>
# ----> 1 Map.save(outfile='Map.html')
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in save(self, outfile, close_file, **kwargs)
#     167
#     168         root = self.get_root()
# --> 169         html = root.render(**kwargs)
#     170         fid.write(html.encode('utf8'))
#     171         if close_file:
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in render(self, **kwargs)
#     319         """Renders the HTML representation of the element."""
#     320         for name, child in self._children.items():
# --> 321             child.render(**kwargs)
#     322         return self._template.render(this=self, kwargs=kwargs)
#     323
#
# ~/.local/lib/python3.6/site-packages/folium/folium.py in render(self, **kwargs)
#     368             '</style>'), name='map_style')
#     369
# --> 370         super(Map, self).render(**kwargs)
#     371
#     372     def fit_bounds(self, bounds, padding_top_left=None,
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in render(self, **kwargs)
#     631
#     632         for name, element in self._children.items():
# --> 633             element.render(**kwargs)
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in render(self, **kwargs)
#    1168             self.color_scale._parent = self._parent
#    1169
# -> 1170         super(Choropleth, self).render(**kwargs)
#    1171
#    1172
#
# ~/.local/lib/python3.6/site-packages/branca/element.py in render(self, **kwargs)
#     631
#     632         for name, element in self._children.items():
# --> 633             element.render(**kwargs)
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in render(self, **kwargs)
#     569                                         self)
#     570             if self.style:
# --> 571                 self.style_map = mapper.get_style_map(self.style_function)
#     572             if self.highlight:
#     573                 self.highlight_map = mapper.get_highlight_map(
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in get_style_map(self, style_function)
#     589     def get_style_map(self, style_function):
#     590         """Return a dict that maps style parameters to features."""
# --> 591         return self._create_mapping(style_function, 'style')
#     592
#     593     def get_highlight_map(self, highlight_function):
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in _create_mapping(self, func, switch)
#     599         mapping = {}
#     600         for feature in self.data['features']:
# --> 601             content = func(feature)
#     602             if switch == 'style':
#     603                 for key, value in content.items():
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in style_function(x)
#    1128
#    1129         def style_function(x):
# -> 1130             color, opacity = color_scale_fun(x)
#    1131             return {
#    1132                 'weight': line_weight,
#
# ~/.local/lib/python3.6/site-packages/folium/features.py in color_scale_fun(x)
#    1121
#    1122                 color_idx = np.digitize(value_of_x, bin_edges, right=False) - 1
# -> 1123                 return color_range[color_idx], fill_opacity
#    1124
#    1125         else:
#
# IndexError: list index out of range

# %%
"df: {}".format(len(df)), "geo_json_data: {}".format(len(geo_json_data)), "df_gp: {}".format(len(df_gp))

# %%
df = df.sort_values(['district'],ascending=True)
df_gp = df_gp.sort_values(['district'],ascending=True)

s1 = df['district'].tolist()
s2 = df_gp['district'].tolist()

dff = pd.DataFrame()
se1 = pd.Series(s1)
se2 = pd.Series(s2)
dff['District'] = se1.values
dff['district'] = se2.values

dff.head(40)
